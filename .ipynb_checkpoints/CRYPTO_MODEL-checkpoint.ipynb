# %% [markdown]
# # STOCK/CRPYTO PRICE PREDICTION MODEL
#
# ## The following code is an example on how to use simple data analysis tolls in order to set up a simple strategy for long and short term financial trading
#
# ### We will make use of the programing language python (3.x) which suits nicely for data anlysis

# %% [markdown]
# ## --> This a very is simplified model for trading. One should always invest just as much money as one can afford to loose and do own studies in advance.

# %% [markdown]
# ## Required modules:
# - numpy: the code is designed to be vectorized such that the numpy module can be used and calculations performed fast
# - pandas: module for illustrative data frames
# - yfinance: api module provided by yahoo finance to get current and previous asset prices
# - matplotlib: (sub)module(s) for plots
# - scipy: (sub)module for statistical and signal analysis
# - datetime: (optional)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from model import MODEL
import utils, plotting, statistics
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
tickers = ['BTC-USD', 'LTC-USD', 'XRP-USD']
tickers = 'BTC-USD'
model = MODEL(tickers=tickers)

# %%
start_date = '2020-01-01'
model.get_data(start=start_date, interval='60m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#edit this:
day_hour = 18
#do not edit below this line:
start_date_range = pd.Timestamp(2020, 1, 1, day_hour)
date_range = utils.create_date_range(start_date=start_date_range)
model.apply_date_filter(date_range)
model.data.tail()
# Out:
# [INFO]: filter applied.
#                                BTC-USD
# Datetime
# 2020-04-13 18:00:00+01:00  6760.631836
# 2020-04-14 18:00:00+01:00  6934.579102
# 2020-04-15 18:00:00+01:00  6724.846191
# 2020-04-16 18:00:00+01:00  7021.342285
# 2020-04-17 18:00:00+01:00  7082.226562

# %%
model.eval_model()
# Out:
# ==================================================================================
# |                                  PRICE MODEL                                   |
# |                                  Version 0.3                                   |
# |                   Authors: Marco Rosenzweig & Patrick Lorenz                   |
# ----------------------------------------------------------------------------------
# |                              ticker = ['BTC-USD']                              |
# |                             start date = 01/01/20                              |
# |                              end date = 04/17/20                               |
# |                      initial investment per ticker = 200                       |
# ==================================================================================
# [INIT]: Initialising model for tickers: ['BTC-USD']
# [INIT]: Successfully initialized model.
# **********************************************************************************
# [TICKER]: BTC-USD
# [INFO]: Open position.
# [INFO]: No tax paid.
# [INFO]: Last entry of "Sell Dates" will be assigned equally as the penultimate one.
# ----------------------------------------------------------------------------------
# [SUMMARY]: Average trade win: 5.9076326835%
# [SUMMARY]: Average trade loss: -1.1289774467%
# [SUMMARY]: Efficiency: 77.78%
# [SUMMARY]: NET WIN: 218.16
# ==================================================================================

# %%
model.data
# Out:
#                                BTC-USD
# Datetime
# 2020-01-01 18:00:00+00:00  7238.930664
# 2020-01-02 18:00:00+00:00  6999.171387
# 2020-01-03 18:00:00+00:00  7373.281250
# 2020-01-04 18:00:00+00:00  7354.490234
# 2020-01-05 18:00:00+00:00  7536.349121
# ...                                ...
# 2020-04-13 18:00:00+01:00  6760.631836
# 2020-04-14 18:00:00+01:00  6934.579102
# 2020-04-15 18:00:00+01:00  6724.846191
# 2020-04-16 18:00:00+01:00  7021.342285
# 2020-04-17 18:00:00+01:00  7082.226562
#
# [108 rows x 1 columns]

# %%
model.ticker_df['BTC-USD']
# Out:
#              Buy Dates          Sell Dates    Buy Prices   Sell Prices  \
# 0  2020-01-10 18:00:00 2020-01-11 18:00:00   8056.407841   8092.316211
# 1  2020-01-13 18:00:00 2020-01-15 18:00:00   8159.626720   8710.168962
# 2  2020-01-20 18:00:00 2020-01-22 18:00:00   8703.297439   8635.120274
# 3  2020-01-23 18:00:00 2020-01-30 18:00:00   8372.618587   9450.361622
# 4  2020-02-04 18:00:00 2020-02-06 18:00:00   9215.028143   9684.722914
# 5  2020-02-08 18:00:00 2020-02-09 18:00:00   9854.609010  10013.333228
# 6  2020-02-11 18:00:00 2020-02-12 18:00:00  10167.854639  10278.565529
# 7  2020-02-16 18:00:00 2020-02-19 18:00:00   9843.817061  10121.483827
# 8  2020-02-21 18:00:00 2020-02-23 18:00:00   9737.208008   9833.696578
# 9  2020-02-26 18:00:00 2020-03-03 18:00:00   8823.553376   8684.136919
# 10 2020-03-04 18:00:00 2020-03-06 18:00:00   8771.298760   9045.157029
# 11 2020-03-09 18:00:00 2020-03-11 18:00:00   7786.559673   7725.586647
# 12 2020-03-13 18:00:00 2020-03-20 18:00:00   5039.419714   6242.962162
# 13 2020-03-23 18:00:00 2020-03-24 18:00:00   6293.238635   6622.449664
# 14 2020-03-29 17:00:00 2020-03-31 17:00:00   6141.872720   6403.768838
# 15 2020-04-01 17:00:00 2020-04-03 17:00:00   6237.840652   6692.664247
# 16 2020-04-05 17:00:00 2020-04-07 17:00:00   6803.486536   7296.204720
# 17 2020-04-11 17:00:00 2020-04-13 17:00:00   6822.970610   6729.532929
# 18 2020-04-14 17:00:00 2020-04-13 17:00:00   6954.689381           NaN
#
#     Trade Reward  Trade Win  Trade Efficiency
# 0     200.891424   0.891424          0.004457
# 1     214.445869  13.554445          0.067471
# 2     212.766010  -1.679859         -0.007833
# 3     240.153749  27.387738          0.128722
# 4     252.394510  12.240761          0.050971
# 5     256.459727   4.065217          0.016107
# 6     259.252143   2.792416          0.010888
# 7     266.564927   7.312784          0.028207
# 8     269.206389   2.641462          0.009909
# 9     264.952796  -4.253593         -0.015800
# 10    273.225176   8.272380          0.031222
# 11    271.085673  -2.139503         -0.007831
# 12    335.827873  64.742199          0.238826
# 13    353.395654  17.567781          0.052312
# 14    368.464828  15.069174          0.042641
# 15    395.330936  26.866108          0.072914
# 16    423.961365  28.630429          0.072421
# 17    418.155394  -5.805971         -0.013695
# 18           NaN        NaN               NaN

# %%
plotting.plot_model(model, plot_from_date='2020-04-01')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x13316f550>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x13317c050>)

# %%
imag_model = model.copy_model()

# %%
imag_model.append_timedelta(timedelta=1)
# Out:
# [USER INPUT]: Overwrite existing data? y

# %%
imag_model.data
# Out:
#                                BTC-USD
# 2020-01-01 18:00:00+00:00  7238.930664
# 2020-01-02 18:00:00+00:00  6999.171387
# 2020-01-03 18:00:00+00:00  7373.281250
# 2020-01-04 18:00:00+00:00  7354.490234
# 2020-01-05 18:00:00+00:00  7536.349121
# ...                                ...
# 2020-04-14 18:00:00+01:00  6934.579102
# 2020-04-15 18:00:00+01:00  6724.846191
# 2020-04-16 18:00:00+01:00  7021.342285
# 2020-04-17 18:00:00+01:00  7082.226562
# 2020-04-18 18:00:00+01:00          NaN
#
# [109 rows x 1 columns]

# %%
imag_model.comp_break_values(['BTC-USD', 'LTC-USD'])
# Out:
# [WARNING]: Ticker "LTC-USD" not in available tickers
# [INFO]: Compute break values with 30.00% deviation
# [USER INPUT]: Append breaking values w.r.t smallest tolerances? n
# [INFO]: Current values: {'BTC-USD': 7082.2265625}
# [INFO]: Break values: {'BTC-USD': [7138.884375000616, 7123.303476563112]}
# [INFO]: Tolerances: {'BTC-USD': array([56.6578125 , 41.07691406])}

# %%
for ticker in imag_model.tickers:
    print('Current ticker: {}'.format(ticker))
    print('Last 2 values in data set: {}'.format(imag_model.data[ticker].values[-2:]))
    print('Break values: {}'.format(imag_model.break_values[ticker]))
    print('Tolerances: {}'.format(imag_model.tolerances[ticker]))
    print('#' * 10)
# Out:
# Current ticker: BTC-USD
# Last 2 values in data set: [7082.2265625          nan]
# Break values: [7138.884375000616, 7123.303476563112]
# Tolerances: [56.6578125  41.07691406]
# ##########

# %%
imag_model._init_model()
imag_model.data.tail(1)
# Out:
# [INIT]: Initialising model for tickers: ['BTC-USD']
# [INIT]: Successfully initialized model.
# **********************************************************************************
#                            BTC-USD
# 2020-04-18 18:00:00+01:00      NaN

# %%
imag_model.show_possibilities(plot_from_date='2020-04-01')
# Out:
# [INFO]: Current ticker: BTC-USD
# ----------------------------------------------------------------------------------
# [INFO]: New sell signal was detected for last value: 6767.138302734956.
# ----------------------------------------------------------------------------------
# [INFO]: New sell signal was detected for last value: 7131.0939257818645.
# ----------------------------------------------------------------------------------

# %%
stats_data = utils.download_data(tickers='BTC-USD', start='2019-01-01', interval='60m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
statistics.calc_probs(model=imag_model, stats_data=stats_data, auto_update_tolerances=True)
# Out:
# [INFO]: Auto update of tolerances!
# [*********************100%***********************]  1 of 1 completed
# [INFO]: Current value: 7217.85205078125!
# [INFO]: New tolerances: [-78.96767578 -94.54857422]!
# Probability for reaching smallest tolerance: 99.48262054637192%
# Probability for reaching highest tolerance: 95.60380172009626%
# Probability between: 3.878818826275662%

# %%
#TODO: Implement this: 
#from model import STATISTICAL_MODEL
#stat_model = STATISTICAL_MODEL(imag_model)

# %%
utils.download_data(tickers='BTC-USD', start=pd.Timestamp.today(), value='Close').values[-1]
# Out:
# [*********************100%***********************]  1 of 1 completed
# 7217.64013671875
