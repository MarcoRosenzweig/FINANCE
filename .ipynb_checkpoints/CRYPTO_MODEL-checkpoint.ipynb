# %% [markdown]
# # STOCK/CRPYTO PRICE PREDICTION MODEL
#
# ## The following code is an example on how to use simple data analysis tolls in order to set up a simple strategy for long and short term financial trading
#
# ### We will make use of the programing language python (3.x) which suits nicely for data anlysis

# %% [markdown]
# ## --> This a very is simplified model for trading. One should always invest just as much money as one can afford to loose and do own studies in advance.

# %% [markdown]
# ## Required modules:
# - numpy: the code is designed to be vectorized such that the numpy module can be used and calculations performed fast
# - pandas: module for illustrative data frames
# - yfinance: api module provided by yahoo finance to get current and previous asset prices
# - matplotlib: (sub)module(s) for plots
# - scipy: (sub)module for statistical and signal analysis

# %% [markdown]
# ### CELLS YOU DO NOT NEED TO EXECUTE:

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### CELLS YOU CAN EXECUTE OPTIONALLY:

# %% [markdown]
# #### --> This does not toggle the output of a cell:

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %% [markdown]
# ### CELLS YOU NEED TO EXECUTE IN ORDER TO BE UP-TO-DATE:

# %%
your_path_to_folder_called_FINANCE = '###INSERT YOUR PATH HERE###'
import sys
sys.path.append(your_path_to_folder_called_FINANCE)

# %%
from model import MODEL
import utils, plotting, statistics
import pandas as pd

# %% [markdown]
# ### CELLS YOU CAN MODIFY:

# %% [markdown]
# #### WARNING: Do not mix tickers from different markets/timezones. This can result in various NaN values if a filter is applied!

# %%
start_date = '2020-01-01' #your start date for the model.
day_hour = 16 #your intra-day time at which to evaluate the model.
tickers = ['BTC-USD', 'LTC-USD', 'XRP-USD'] #your tickers of interest.

# %% [markdown]
# ### The main part starts here:

# %%
model = MODEL(tickers=tickers)
model.get_data(start=start_date, interval='60m')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
start_date_range = pd.Timestamp(2020, 1, 1, day_hour)
date_range = utils.create_date_range(start_date=start_date_range)
model.apply_date_filter(date_range)
model.data.tail()
# Out:
# [WARNING]: Filter would result in 3 NaN values.
# [USER-INPUT]: Remove NaN values?: y
# [INFO]: filter applied.
#                                BTC-USD    LTC-USD   XRP-USD
# Datetime
# 2020-04-14 16:00:00+01:00  6921.086914  41.466686  0.187773
# 2020-04-15 16:00:00+01:00  6723.213379  40.379490  0.183197
# 2020-04-16 16:00:00+01:00  7053.479492  42.675785  0.189295
# 2020-04-17 16:00:00+01:00  7087.016113  42.438065  0.189091
# 2020-04-18 16:00:00+01:00  7233.656738  43.707947  0.194079

# %%
model.eval_model()
# Out:
# ==================================================================================
# |                                  PRICE MODEL                                   |
# |                                  Version 0.3                                   |
# |                   Authors: Marco Rosenzweig & Patrick Lorenz                   |
# ----------------------------------------------------------------------------------
# |                   ticker = ['BTC-USD', 'LTC-USD', 'XRP-USD']                   |
# |                             start date = 01/01/20                              |
# |                              end date = 04/18/20                               |
# |                      initial investment per ticker = 200                       |
# ==================================================================================
# [INIT]: Initialising model for tickers: ['BTC-USD', 'LTC-USD', 'XRP-USD']
# [WARNING]: Ignoring second entry of gradient!
# [INIT]: Successfully initialized model.
# **********************************************************************************
# [TICKER]: BTC-USD
# [INFO]: Open position.
# [INFO]: No tax paid.
# [INFO]: Last entry of "Sell Dates" will be assigned equally as the penultimate one.
# ----------------------------------------------------------------------------------
# [SUMMARY]: Average trade win: 5.9921305956%
# [SUMMARY]: Average trade loss: -0.8802410143%
# [SUMMARY]: Efficiency: 73.68%
# [SUMMARY]: NET WIN: 225.80
# ==================================================================================
# [TICKER]: LTC-USD
# [INFO]: Open position.
# [INFO]: No tax paid.
# [INFO]: Last entry of "Sell Dates" will be assigned equally as the penultimate one.
# ----------------------------------------------------------------------------------
# [SUMMARY]: Average trade win: 6.7238494255%
# [SUMMARY]: Average trade loss: -3.6081428796%
# [SUMMARY]: Efficiency: 89.47%
# [SUMMARY]: NET WIN: 351.63
# ==================================================================================
# [TICKER]: XRP-USD
# [INFO]: Open position.
# [INFO]: No tax paid.
# [INFO]: Last entry of "Sell Dates" will be assigned equally as the penultimate one.
# ----------------------------------------------------------------------------------
# [SUMMARY]: Average trade win: 5.5678985490%
# [INFO]: Current ticker: BTC-USD
# [INFO]: Current ticker: LTC-USD
# [INFO]: Current ticker: XRP-USD
# [USER-INPUT]: Append breaking values w.r.t smallest tolerances? n
# [INFO]: Current values: {'BTC-USD': 7233.65673828125, 'LTC-USD': 43.70794677734375, 'XRP-USD': 0.19407927989959717}
# [INFO]: Break values: {'BTC-USD': [7334.927932617059, 7246.677320410033], 'LTC-USD': [44.33734121093926, 43.200934594728174], 'XRP-USD': [0.19621415197849895, 0.1913233541250286]}
# [INFO]: Tolerances: {'BTC-USD': array([101.27119434,  13.02058213]), 'LTC-USD': array([ 0.62939443, -0.50701218]), 'XRP-USD': array([ 0.00213487, -0.00275593])}

# %%
imag_model._init_model()
imag_model.data.tail(5)
# Out:
# [INIT]: Initialising model for tickers: ['BTC-USD', 'LTC-USD', 'XRP-USD']
# [WARNING]: Ignoring second entry of gradient!
# [INIT]: Successfully initialized model.
# **********************************************************************************
#                                BTC-USD    LTC-USD   XRP-USD
# 2020-04-15 16:00:00+01:00  6723.213379  40.379490  0.183197
# 2020-04-16 16:00:00+01:00  7053.479492  42.675785  0.189295
# 2020-04-17 16:00:00+01:00  7087.016113  42.438065  0.189091
# 2020-04-18 16:00:00+01:00  7233.656738  43.707947  0.194079
# 2020-04-19 16:00:00+01:00          NaN        NaN       NaN

# %%
imag_model.show_possibilities(plot_from_date='2020-04-01', switch_axes=True)
# Out:
# ==================================================================================
# [INFO]: Current ticker: BTC-USD
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 7156.0938539049075
# [INFO]: New sell signal was detected for last value: 7156.0938539049075.
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 7290.802626513546
# [INFO]: New sell signal was detected for last value: 7290.802626513546.
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 7426.614531774772
# ==================================================================================
# [INFO]: Current ticker: LTC-USD
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 42.660922912294076
# [INFO]: New sell signal was detected for last value: 42.660922912294076.
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 43.76913790283372
# [INFO]: New sell signal was detected for last value: 43.76913790283372.
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 44.891557976075994
# ==================================================================================
# [INFO]: Current ticker: XRP-USD
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 0.18893181219846575
# [INFO]: New sell signal was detected for last value: 0.18893181219846575.
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 0.19376875305176378
# [INFO]: New sell signal was detected for last value: 0.19376875305176378.
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 0.19866682887823017

# %%
statistics.calc_probs(model=imag_model, auto_update_tolerances=True)
# Out:
# ==================================================================================
# [INFO]: Current ticker: BTC-USD
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Auto update of tolerances!
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Current value: 7171.6142578125!
# [STATS-INFO]: New tolerances: [163.3136748  75.0630626]!
# [STATS-EVAL]: Probability for tol=75.06306: 41.35%
# [STATS-EVAL]: Probability for tol=163.31367: 31.59%
# [STATS-EVAL]: Probability between: 9.77%
# ==================================================================================
# [INFO]: Current ticker: LTC-USD
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Auto update of tolerances!
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Current value: 42.80598831176758!
# [STATS-INFO]: New tolerances: [1.5313529  0.39494628]!
# [STATS-EVAL]: Probability for tol=0.39495: 45.73%
# [STATS-EVAL]: Probability for tol=1.53135: 33.69%
# [STATS-EVAL]: Probability between: 12.04%
# ==================================================================================
# [INFO]: Current ticker: XRP-USD
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Auto update of tolerances!
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Current value: 0.1920536905527115!
# [STATS-INFO]: New tolerances: [ 0.00416046 -0.00073034]!
# [STATS-EVAL]: Probability for tol=-0.00073: 51.37%
# [STATS-EVAL]: Probability for tol=0.00416: 35.25%
# [STATS-EVAL]: Probability between: 16.12%

# %%
#TODO: Implement this: 
#from model import STATISTICAL_MODEL
#stat_model = STATISTICAL_MODEL(imag_model)
