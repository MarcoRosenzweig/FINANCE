# %% [markdown]
# # STOCK/CRPYTO PRICE PREDICTION MODEL
#
# ## The following code is an example on how to use simple data analysis tolls in order to set up a simple strategy for long and short term financial trading
#
# ### We will make use of the programing language python (3.x) which suits nicely for data anlysis

# %% [markdown]
# ## --> This a very is simplified model for trading. One should always invest just as much money as one can afford to loose and do own studies in advance.

# %% [markdown]
# ## Required modules:
# - numpy: the code is designed to be vectorized such that the numpy module can be used and calculations performed fast
# - pandas: module for illustrative data frames
# - yfinance: api module provided by yahoo finance to get current and previous asset prices
# - matplotlib: (sub)module(s) for plots
# - scipy: (sub)module for statistical and signal analysis

# %% [markdown]
# ### CELLS YOU DO NOT NEED TO EXECUTE:

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### CELLS YOU CAN EXECUTE OPTIONALLY:

# %% [markdown]
# #### --> This does not toggle the output of a cell:

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %% [markdown]
# ### CELLS YOU NEED TO EXECUTE IN ORDER TO BE UP-TO-DATE:

# %%
your_path_to_folder_called_FINANCE = '###INSERT YOUR PATH HERE###'
import sys
sys.path.append(your_path_to_folder_called_FINANCE)

# %%
from model import MODEL
import utils, plotting, statistics
import pandas as pd

# %% [markdown]
# ### CELLS YOU CAN MODIFY:

# %% [markdown]
# #### WARNING: Do not mix tickers from different markets/timezones. This can result in various NaN values if a filter is applied!

# %%
start_date = '2019-06-01' #your start date for the model.
day_hour = 18 #your intra-day time at which to evaluate the model.
tickers = ['BTC-USD', 'LTC-USD', 'XRP-USD'] #your tickers of interest.
#tickers = 'BTC-USD'

# %% [markdown]
# ### The main part starts here:

# %%
model = MODEL(tickers=tickers, periods=(50, 200, 100))
model.get_data(start=start_date, interval='60m')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
start_date_range = pd.Timestamp(2019, 6, 1, day_hour)
date_range = utils.create_date_range(start_date=start_date_range)
model.apply_date_filter(date_range)
model.data.tail()
# Out:
# [WARNING]: Filter would result in 26 NaN values.
# [USER-INPUT]: Remove NaN values?: y
# [INFO]: filter applied.
#                                BTC-USD    LTC-USD   XRP-USD
# Datetime
# 2020-04-15 18:00:00+01:00  6724.846191  40.433876  0.184323
# 2020-04-16 18:00:00+01:00  7021.342285  42.444279  0.187972
# 2020-04-17 18:00:00+01:00  7082.226562  42.499939  0.189167
# 2020-04-18 18:00:00+01:00  7233.494141  43.709045  0.194548
# 2020-04-19 18:00:00+01:00  7216.310547  43.112511  0.192525

# %%
model.eval_model()
# Out:
# ==================================================================================
# |                                  PRICE MODEL                                   |
# |                                  Version 0.3                                   |
# |                   Authors: Marco Rosenzweig & Patrick Lorenz                   |
# ----------------------------------------------------------------------------------
# |                   ticker = ['BTC-USD', 'LTC-USD', 'XRP-USD']                   |
# |                             start date = 06/03/19                              |
# |                              end date = 04/19/20                               |
# |                      initial investment per ticker = 200                       |
# ==================================================================================
# [INIT]: Initialising model for tickers: ['BTC-USD', 'LTC-USD', 'XRP-USD']
# [WARNING]: Ignoring second entry of gradient!
# [INIT]: Successfully initialized model.
# **********************************************************************************
# [TICKER]: BTC-USD
# [INFO]: 359.75 tax was paid.
# ----------------------------------------------------------------------------------
# [SUMMARY]: Average trade win: 5.9853899466%
# [SUMMARY]: Average trade loss: -0.8066282407%
# [SUMMARY]: Efficiency: 84.44%
# [SUMMARY]: NET WIN: 1079.24
# ==================================================================================
# [TICKER]: LTC-USD
# [INFO]: 661.85 tax was paid.
# ----------------------------------------------------------------------------------
# [SUMMARY]: Average trade win:
# 35 2020-02-29 18:00:00 2020-03-03 18:00:00   8712.151165   8684.136919
# 36 2020-03-04 18:00:00 2020-03-06 18:00:00   8771.298760   9045.157029
# 37 2020-03-10 18:00:00 2020-03-11 18:00:00   7900.111654   7725.586647
# 38 2020-03-14 18:00:00 2020-03-21 18:00:00   5504.575312   6146.950292
# 39 2020-03-22 18:00:00 2020-03-27 18:00:00   6021.004172   6632.619463
# 40 2020-03-29 17:00:00 2020-03-31 17:00:00   6142.723324   6408.761391
# 41 2020-04-01 17:00:00 2020-04-03 17:00:00   6237.840652   6692.664247
# 42 2020-04-04 17:00:00 2020-04-08 17:00:00   6783.407968   7256.446073
# 43 2020-04-11 17:00:00 2020-04-12 17:00:00   6822.970610   7032.383866
# 44 2020-04-15 17:00:00 2020-04-19 17:00:00   6744.348245   7183.115518
#
#     Trade Reward   Trade Win  Trade Efficiency
# 0     200.718535    0.718535          0.003593
# 1     220.220547   19.502012          0.097161
# 2     234.045363   13.824816          0.062777
# 3     258.620765   24.575402          0.105003
# 4     261.456971    2.836207          0.010967
# 5     318.482360   57.025388          0.218106
# 6     339.413240   20.930880          0.065721
# 7     345.139165    5.725925          0.016870
# 8     346.113469    0.974304          0.002823
# 9     383.482621   37.369152          0.107968
# 10    391.469616    7.986995          0.020828
# 11    386.126900   -5.342715         -0.013648
# 12    405.906174   19.779274          0.051225
# 13    401.840829   -4.065345         -0.010015
# 14    410.371964    8.531135          0.021230
# 15    505.975313   95.603348          0.232968
# 16    503.144482   -2.830831         -0.005595
# 17    513.180584   10.036102          0.019947
# 18    512.432440   -0.748145         -0.001458
# 19    513.978975    1.546535          0.003018
# 20    540.397086   26.418111          0.051399
# 21    556.575501   16.178415          0.029938
# 22    556.330052   -0.245449         -0.000441
# 23    602.153641   45.823588          0.082368
# 24    617.670508   15.516867          0.025769
# 25    712.081798   94.411291          0.152851
# 26    716.984181    4.902383          0.006885
# 27    765.360178   48.375997          0.067471
# 28    778.018191   12.658013          0.016539
# 29    877.915524   99.897334          0.128400
# 30    927.504476   49.588952          0.056485
# 31    942.443417   14.938941          0.016107
# 32    952.705046   10.261629          0.010888
# 33    998.463132   45.758086          0.048030
# 34   1008.357167    9.894035          0.009909
# 35   1005.114757   -3.242410         -0.003216
# 36   1036.496539   31.381782          0.031222
# 37   1013.598816  -22.897723         -0.022091
# 38   1131.884149  118.285332          0.116698
# 39   1246.861258  114.977109          0.101580
# 40   1300.862153   54.000895          0.043309
# 41   1395.712732   94.850579          0.072914
# 42   1493.042173   97.329441          0.069735
# 43   1538.867202   45.825028          0.030692
# 44   1638.981333  100.114131          0.065057

# %%
plotting.plot_model(model, tickers='all', plot_from_date='2020-04-01')
# Out:
# [INFO]: New sell signal was detected for last value: 7216.310546875.
# [INFO]: New sell signal was detected for last value: 43.112510681152344.
# [INFO]: New sell signal was detected for last value: 0.19252489507198334.

# %%
imag_model = model.copy_model()

# %%
imag_model.append_timedelta(timedelta=1)
# Out:
# [USER-INPUT]: Overwrite existing data? y

# %%
imag_model.data.tail(5)
# Out:
#                                BTC-USD    LTC-USD   XRP-USD
# 2020-04-16 18:00:00+01:00  7021.342285  42.444279  0.187972
# 2020-04-17 18:00:00+01:00  7082.226562  42.499939  0.189167
# 2020-04-18 18:00:00+01:00  7233.494141  43.709045  0.194548
# 2020-04-19 18:00:00+01:00  7216.310547  43.112511  0.192525
# 2020-04-20 18:00:00+01:00          NaN        NaN       NaN

# %%
imag_model.comp_break_values()
# Out:
# [INFO]: Compute break values with 30.00% deviation
# [INFO]: Current ticker: BTC-USD
# [INFO]: Current ticker: LTC-USD
# [INFO]: Current ticker: XRP-USD
# [USER-INPUT]: Append breaking values w.r.t smallest tolerances? n
# [INFO]: Current values: {'BTC-USD': 7216.310546875, 'LTC-USD': 43.112510681152344, 'XRP-USD': 0.19252489507198334}
# [INFO]: Break values: {'BTC-USD': [7236.516216405796, 7274.041031249538], 'LTC-USD': [43.0952656768796, 43.70746332855195], 'XRP-USD': [0.19294844984113477, 0.19552828343509904]}
# [INFO]: Tolerances: {'BTC-USD': array([20.20566953, 57.73048437]), 'LTC-USD': array([-0.017245  ,  0.59495265]), 'XRP-USD': array([0.00042355, 0.00300339])}

# %%
imag_model._init_model()
imag_model.data.tail(5)
# Out:
# [INIT]: Initialising model for tickers: ['BTC-USD', 'LTC-USD', 'XRP-USD']
# [WARNING]: Ignoring second entry of gradient!
# [INIT]: Successfully initialized model.
# **********************************************************************************
#                                BTC-USD    LTC-USD   XRP-USD
# 2020-04-16 18:00:00+01:00  7021.342285  42.444279  0.187972
# 2020-04-17 18:00:00+01:00  7082.226562  42.499939  0.189167
# 2020-04-18 18:00:00+01:00  7233.494141  43.709045  0.194548
# 2020-04-19 18:00:00+01:00  7216.310547  43.112511  0.192525
# 2020-04-20 18:00:00+01:00          NaN        NaN       NaN

# %%
imag_model.show_possibilities(plot_from_date='2020-04-01', switch_axes=True)
# Out:
# ==================================================================================
# [INFO]: Current ticker: BTC-USD
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 7146.059763700723
# [INFO]: New sell signal was detected for last value: 7146.059763700723.
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 7255.278623827667
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 7364.966544140157
# ==================================================================================
# [INFO]: Current ticker: LTC-USD
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 42.556574855918605
# [INFO]: New sell signal was detected for last value: 42.556574855918605.
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 43.40136450271578
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 44.25380662015885
# ==================================================================================
# [INFO]: Current ticker: XRP-USD
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 0.19053659421812058
# [INFO]: New sell signal was detected for last value: 0.19053659421812058.
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 0.1942383666381169
# ----------------------------------------------------------------------------------
# [INFO]: Result for value: 0.19797238697803776

# %%
statistics.calc_probs(model=imag_model, tickers='all', auto_update_tolerances=True)
# Out:
# ==================================================================================
# [INFO]: Current ticker: BTC-USD
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Auto update of tolerances!
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Current value: 7196.1494140625!
# [STATS-INFO]: New tolerances: [40.36680234 77.89161719]!
# [STATS-EVAL]: Probability for tol=40.36680: 45.01%
# [STATS-EVAL]: Probability for tol=77.89162: 39.85%
# [STATS-EVAL]: Probability between: 5.16%
# ==================================================================================
# [INFO]: Current ticker: LTC-USD
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Auto update of tolerances!
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Current value: 43.00629806518555!
# [STATS-INFO]: New tolerances: [0.08896761 0.70116526]!
# [STATS-EVAL]: Probability for tol=0.08897: 49.19%
# [STATS-EVAL]: Probability for tol=0.70117: 41.71%
# [STATS-EVAL]: Probability between: 7.48%
# ==================================================================================
# [INFO]: Current ticker: XRP-USD
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Auto update of tolerances!
# [*********************100%***********************]  1 of 1 completed
# [STATS-INFO]: Current value: 0.19179512560367584!
# [STATS-INFO]: New tolerances: [0.00115332 0.00373316]!
# [STATS-EVAL]: Probability for tol=0.00115: 44.66%
# [STATS-EVAL]: Probability for tol=0.00373: 35.20%
# [STATS-EVAL]: Probability between: 9.45%
